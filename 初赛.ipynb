# %%
import pandas as pd
from tqdm import tqdm
import warnings
import gc
import os
import lightgbm as lgb
from sklearn.model_selection import GroupKFold, KFold
from sklearn.preprocessing import LabelEncoder
from gensim.models import Word2Vec
from collections import OrderedDict
from sklearn.feature_extraction.text import TfidfVectorizer
from pandarallel import pandarallel
import time

pandarallel.initialize()

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

warnings.filterwarnings('ignore')
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
# !pip install pandarallel

# %%
seed = 2020

# %%
train_feature = pd.read_pickle('data/train_data.pkl')
test_feature = pd.read_pickle('data/test_data.pkl')
train_log = pd.read_pickle('data/train_log.pkl')
test_log = pd.read_pickle('data/test_log.pkl')

# %%
df_feature = train_feature.append(test_feature)
df_feature.reset_index(drop=True, inplace=True)
df_feature = df_feature[['userid', 'productId', 'target']]

df_log = train_log.append(test_log)
df_log.reset_index(drop=True, inplace=True)
df_log.sort_values(['eventtime'], inplace=True)

# %%
print('训练集正样本数', df_feature[df_feature['target'] == 1].shape[0])
print('训练集负样本数', df_feature[df_feature['target'] == 0].shape[0])
print('测试集样本数', df_feature['target'].isnull().sum())
# Out:
# 训练集正样本数 19870
# 训练集负样本数 407000
# 测试集样本数 292268

# %%
df_feature.shape
# Out:
# (719138, 3)

# %% [markdown]
# # 特征工程

# %%
# embedding
def emb_mean(df, f1, f2, emb_size=16):
    tmp = df.groupby(f1, as_index=False)[f2].agg(
        {'{}_{}_list'.format(f1, f2): list})
    sentences = tmp['{}_{}_list'.format(f1, f2)].values.tolist()
    del tmp['{}_{}_list'.format(f1, f2)]
    for i in range(len(sentences)):
        sentences[i] = [str(x) for x in sentences[i]]
    
    if os.path.exists('model/w2v_{}_{}.m'.format(f2, emb_size)):
        model = Word2Vec.load('model/w2v_{}_{}.m'.format(f2, emb_size))
    else:
        model = Word2Vec(sentences, size=emb_size, window=5,
                     min_count=1, sg=0, hs=1, seed=seed)
        model.save('model/w2v_{}_{}.m'.format(f2, emb_size))

    emb_matrix = []
    for seq in sentences:
        vec = []
        for w in seq:
            if w in model:
                vec.append(model[w])
        if len(vec) > 0:
            emb_matrix.append(np.mean(vec, axis=0))
        else:
            emb_matrix.append([0] * emb_size)

    df_emb = pd.DataFrame(emb_matrix)
    df_emb.columns = ['{}_{}_emb_{}'.format(
        f1, f2, i) for i in range(emb_size)]

    tmp = pd.concat([tmp, df_emb], axis=1)

    del model, emb_matrix, sentences
    return tmp

# %%
df_log['lat'] = df_log['lat'].replace('\\N', 0)
df_log['lgt'] = df_log['lgt'].replace('\\N', 0)
df_log['lat_lgt'] = df_log['lat'].astype('str') + '_' + df_log['lgt'].astype('str')
df_log['lat'] = df_log['lat'].astype('float')
df_log['lgt'] = df_log['lgt'].astype('float')

df_log['url_startTime'] = df_log['url_startTime'].astype('float')
df_log['url_startTime_eventtime_diff'] = df_log['eventtime'] - df_log['url_startTime']

# %%
df_log['eventtime_date'] = pd.to_datetime(df_log['eventtime'],unit='ms')
df_log['hour'] = df_log['eventtime_date'].dt.hour

# %%
df_log['time_diff'] = df_log.groupby(['userid'])['eventtime'].diff().fillna(0)

# %%
# df_log['time_category'] = 0
# df_log.loc[(df_log['hour'] > 1) & (df_log['hour'] <= 5), 'time_category'] = 1
# df_log.loc[(df_log['hour'] > 5) & (df_log['hour'] <= 11), 'time_category'] = 2
# df_log.loc[(df_log['hour'] > 11) & (df_log['hour'] <= 14), 'time_category'] = 3
# df_log.loc[(df_log['hour'] > 14) & (df_log['hour'] <= 18), 'time_category'] = 4
# df_log.loc[(df_log['hour'] > 18) & (df_log['hour'] <= 21), 'time_category'] = 5

# %%
# 众数
for f in ['uaos', 'nettype', 'uadevice', 'region', 'city', 'hour']:
    df_temp = df_log.groupby(['userid', f]).size().reset_index()
    df_temp.drop([0], axis=1, inplace=True)
    df_temp = df_temp.sort_values(by = ['userid', f] ,ascending =['asc','asc'])
    df_temp.drop_duplicates('userid', keep='last', inplace=True)
    
    df_feature = df_feature.merge(df_temp, how='left')

# %%
# dict_total = {
#     '20200309387999': 12266, '20200210741736': 6129, '20190815856774': 15024, '20190815675296': 20917,
#     '20180531263676': 35095, '20180531194127': 15055, '20180531390867': 410239, '20180531211243': 237453,
#     '20200218174314': 203667, '20180531184230': 65452, '2020022815278': 55022, '20180530244125': 50775,
#     '20190810782447': 29750, '20190423119297': 28599, '20180531685516': 28215, '20180806735689': 26649,
#     '20180531157314': 26101, '20200301448260': 25694, '20181106538615': 18774, '20190829958079': 17865,
#     '20190508189069': 16765, '2020022175979': 15103, '20200220160007': 14301, '20180614751254': 13450,
#     '20200301801446': 12441, '20200210696720': 10835, '20180531810706': 10833, '20191114199289': 10631,
#     '20200407796159': 9243, '2020031948380': 5854, '20200316644689': 5854, '20191121595608': 5794,
#     '20191126774471': 5030, '2019123176289': 4355, '20200219418368': 3648, '20181106547495': 3266,
#     '20190809905752': 3001, '20200304394802': 2761, '20180531237016': 2752, '20190829850245': 2442,
#     '20191129999329': 2063, '20190129511511': 1846, '20200327987123': 1213, '20200407795677': 353,
#     '20200403495571': 299, '20190222546822': 269, '20191231160884': 255, '20190115978886': 214}
# df_feature['productId_total'] = df_feature['productId'].map(dict_total)

# %%
# dict_money = {
#     '20200309387999': 175, '20200210741736': 100, '20190815856774': 78, '20190815675296': 1,
#     '20180531263676': 68, '20180531194127': 19.6, '20180531390867': 0.7, '20180531211243': 100,
#     '20200218174314': 18, '20180531184230': 70, '2020022815278': 12, '20180530244125': 6.9,
#     '20190810782447': 25, '20190423119297': 0.01, '20180531685516': 38, '20180806735689': 13,
#     '20180531157314': 3, '20200301448260': 0.01, '20181106538615': 12, '20190829958079': 52.8,
#     '20190508189069': 5.8, '2020022175979': 19.9, '20200220160007': 19, '20180614751254': 1,
#     '20200301801446': 12, '20200210696720': 71, '20180531810706': 5, '20191114199289': 1.2,
#     '20200407796159': 2, '2020031948380': 25, '20200316644689': 120, '20191121595608': 1,
#     '20191126774471': 19.9, '2019123176289': 100, '20200219418368': 80, '20181106547495': 25,
#     '20190809905752': 109, '20200304394802': 128, '20180531237016': 10, '20190829850245': 390,
#     '20191129999329': 12, '20190129511511': 300, '20200327987123': 295, '20200407795677': 0.01,
#     '20200403495571': 0.01, '20190222546822': 365, '20191231160884': 6.8, '20190115978886': 220}
# df_feature['productId_money'] = df_feature['productId'].map(dict_money)

# %%
# df_feature['productId_year'] = df_feature['productId'].apply(
#     lambda x: int(x[:4]))
# df_feature['productId_month'] = df_feature['productId'].apply(
#     lambda x: int(x[4:6]))
# df_feature['productId_day'] = df_feature['productId'].apply(
#     lambda x: int(x[6:8]))
# df_feature['productId_time'] = df_feature['productId_year'].astype(
#     str) + '-' + df_feature['productId_month'].astype(str) + '-' + df_feature['productId_day'].astype(str)
# df_feature['productId_time'] = pd.to_datetime(df_feature['productId_time'])
# df_feature['productId_week'] = df_feature['productId_time'].dt.dayofweek
# del df_feature['productId_time']

# %% [markdown]
# ## 最后7天

# %%
df_last_7day_log = df_log[df_log['date'] >= 20200414].copy()
df_last_7day_log.head()
# Out:
#        region       city      eventname      eventtime      lat       lgt  \
# 910052     吉林  Guangdong       32010091  1586793627507  42.7683  129.3364
# 910031     吉林  Guangdong  HCZ_O00005786  1586793627673  42.7683  129.3364
# 910097     吉林  Guangdong       32010091  1586793628009  42.7683  129.3364
# 909925     吉林  Guangdong  HCZ_O00005785  1586793628012  42.7683  129.3364
# 909954     吉林  Guangdong  HCZ_O00013865  1586793628974  42.7683  129.3364
#
#        nettype  title  uadevice uaos    userid      date hzcModule productId  \
# 910052    Wifi     \N  iPhone 7  iOS  74390763  20200414      None      None
# 910031    Wifi     \N  iPhone 7  iOS  74390763  20200414      None      None
# 910097    Wifi  非车险首页  iPhone 7  iOS  74390763  20200414      None      None
# 909925    Wifi  非车险首页  iPhone 7  iOS  74390763  20200414      None      None
# 909954    Wifi  非车险首页  iPhone 7  iOS  74390763  20200414      None      None
#
#        productName  url_startTime           lat_lgt  \
# 910052        None            NaN  42.7683_129.3364
# 910031        None            NaN  42.7683_129.3364
# 910097        None            NaN  42.7683_129.3364
# 909925        None            NaN  42.7683_129.3364
# 909954     周五保险抢购日            NaN  42.7683_129.3364
#
#         url_startTime_eventtime_diff          eventtime_date  hour  \
# 910052                           NaN 2020-04-13 16:00:27.507    16
# 910031                           NaN 2020-04-13 16:00:27.673    16
# 910097                           NaN 2020-04-13 16:00:28.009    16
# 909925                           NaN 2020-04-13 16:00:28.012    16
# 909954                           NaN 2020-04-13 16:00:28.974    16
#
#           time_diff
# 910052  284667421.0
# 910031        166.0
# 910097        336.0
# 909925          3.0
# 909954        962.0

# %%
# 计数
for f in [['productId'], ['userid', 'productId']]:
    df_temp = df_last_7day_log.groupby(f).size().reset_index()
    df_temp.columns = f + ['last_7day_{}_count'.format('_'.join(f))]
    df_feature = df_feature.merge(df_temp, how='left')

# %%
# # mean
# for f in ['hour']:
#     df_temp = df_last_7day_log.groupby('userid')[f].mean().reset_index()
#     df_temp.columns = ['userid'] + ['last_7day_{}_mean'.format(f)]
#     df_feature = df_feature.merge(df_temp, how='left')

# %%
df_feature.head()
# Out:
#    userid       productId  target uaos nettype    uadevice region city  hour  \
# 0   18403  20180530244125     0.0  iOS      \N  iPhone12,1     广东   广州     9
# 1   18403  20180531263676     0.0  iOS      \N  iPhone12,1     广东   广州     9
# 2   18403  20181010361410     0.0  iOS      \N  iPhone12,1     广东   广州     9
# 3   18403  20200221398853     0.0  iOS      \N  iPhone12,1     广东   广州     9
# 4   18403   2019123176289     0.0  iOS      \N  iPhone12,1     广东   广州     9
#
#    last_7day_productId_count  last_7day_userid_productId_count
# 0                      275.0                               NaN
# 1                     5469.0                               NaN
# 2                    33610.0                              10.0
# 3                        4.0                               NaN
# 4                    10247.0                               NaN

# %% [markdown]
# ## 全量统计

# %%
df_log.head()
# Out:
#         region city      eventname      eventtime      lat     lgt nettype  \
# 1118942     广东   广州       11010479  1585670400279  23.1167  113.25    wifi
# 1119349     广东   广州       32010091  1585670400300  23.1167  113.25    wifi
# 1118894     广东   广州  HCZ_O00005786  1585670400305  23.1167  113.25    wifi
# 1119320     广东   广州       32010091  1585670400407  23.1167  113.25    wifi
# 1119272     广东   广州  HCZ_O00005785  1585670400413  23.1167  113.25    wifi
#
#          title  uadevice     uaos    userid      date hzcModule productId  \
# 1118942  平安好车主  LIO-AN00  Android  73959474  20200401      None      None
# 1119349  平安好车主  LIO-AN00  Android  73959474  20200401      None      None
# 1118894  平安好车主  LIO-AN00  Android  73959474  20200401      None      None
# 1119320  非车险首页  LIO-AN00  Android  73959474  20200401      None      None
# 1119272  非车险首页  LIO-AN00  Android  73959474  20200401      None      None
#
#         productName  url_startTime         lat_lgt  \
# 1118942        None            NaN  23.1167_113.25
# 1119349        None            NaN  23.1167_113.25
# 1118894        None            NaN  23.1167_113.25
# 1119320        None            NaN  23.1167_113.25
# 1119272        None            NaN  23.1167_113.25
#
#          url_startTime_eventtime_diff          eventtime_date  hour  time_diff
# 1118942                           NaN 2020-03-31 16:00:00.279    16        0.0
# 1119349                           NaN 2020-03-31 16:00:00.300    16       21.0
# 1118894                           NaN 2020-03-31 16:00:00.305    16        5.0
# 1119320                           NaN 2020-03-31 16:00:00.407    16      102.0
# 1119272                           NaN 2020-03-31 16:00:00.413    16        6.0

# %%
df_temp = df_log[df_log['eventname'] == 'h320057'][['userid', 'productId']].copy()
df_temp = df_temp.groupby(['userid'])['productId'].agg({'productId_click_list': set}).reset_index()
df_feature = df_feature.merge(df_temp, how='left')


def func(x):
    productId = x['productId']
    productId_click_list = x['productId_click_list']
    
    if type(productId_click_list) == float:
        return 0
    
    return productId in productId_click_list

df_feature['is_in_click_history'] = df_feature[['productId', 'productId_click_list']].apply(func, axis=1)
del df_feature['productId_click_list']
df_feature.head()
# Out:
#    userid       productId  target uaos nettype    uadevice region city  hour  \
# 0   18403  20180530244125     0.0  iOS      \N  iPhone12,1     广东   广州     9
# 1   18403  20180531263676     0.0  iOS      \N  iPhone12,1     广东   广州     9
# 2   18403  20181010361410     0.0  iOS      \N  iPhone12,1     广东   广州     9
# 3   18403  20200221398853     0.0  iOS      \N  iPhone12,1     广东   广州     9
# 4   18403   2019123176289     0.0  iOS      \N  iPhone12,1     广东   广州     9
#
#    last_7day_productId_count  last_7day_userid_productId_count  \
# 0                      275.0                               NaN
# 1                     5469.0                               NaN
# 2                    33610.0                              10.0
# 3                        4.0                               NaN
# 4                    10247.0                               NaN
#
#   is_in_click_history
# 0               False
# 1               False
# 2                True
# 3               False
# 4               False

# %%
# 计数
for f in [['productId'], ['userid', 'productId'], ['uaos']]:
    df_temp = df_log.groupby(f).size().reset_index()
    df_temp.columns = f + ['{}_count'.format('_'.join(f))]
    df_feature = df_feature.merge(df_temp, how='left')

# %%
# mean
for f in ['lat', 'url_startTime_eventtime_diff']:
    df_temp = df_log.groupby('userid')[f].mean().reset_index()
    df_temp.columns = ['userid'] + ['{}_mean'.format(f)]
    df_feature = df_feature.merge(df_temp, how='left')
    
# # mean
# for f in ['time_diff']:
#     df_temp = df_log.groupby(['userid', 'productId'])[f].mean().reset_index()
#     df_temp.columns = ['userid', 'productId'] + ['userid_productId_{}_mean'.format(f)]
#     df_feature = df_feature.merge(df_temp, how='left')

# %%
# std
for f in ['hour']:
    df_temp = df_log.groupby('userid')[f].std().reset_index()
    df_temp.columns = ['userid'] + ['{}_std'.format(f)]
    df_feature = df_feature.merge(df_temp, how='left')

# %%
# max
for f in ['eventtime']:
    df_temp = df_log.groupby('userid')[f].max().reset_index()
    df_temp.columns = ['userid'] + ['{}_max'.format(f)]
    df_feature = df_feature.merge(df_temp, how='left')

# %%
# # min
# for f in ['eventtime']:
#     df_temp = df_log.groupby('userid')[f].min().reset_index()
#     df_temp.columns = ['userid'] + ['{}_min'.format(f)]
#     df_feature = df_feature.merge(df_temp, how='left')

# %%
# df_feature['eventtime_max_min_diff'] = df_feature['eventtime_max'] - df_feature['eventtime_min']
# del df_feature['eventtime_min']

# %%
kvs = {
    'eventname': ['11010479', '329000048', 'HCZ_O00013865'],
}
kvs = OrderedDict(kvs)

for k in kvs:
    for v in kvs[k]:
        df_t = df_log.groupby(['userid', k]).size().reset_index()
        df_t = df_t[df_t[k] == v]
        del df_t[k]
        df_t.columns = ['userid', '{}_{}_count'.format(k, v)]
        
        df_feature = df_feature.merge(df_t, how='left')

# %%
for f1, f2, dim in tqdm([['userid', 'title', 16], ['userid', 'productId', 16], ['userid', 'hzcModule', 16], 
                    ['userid', 'eventname', 16]]):
    df_feature = df_feature.merge(emb_mean(df_log, f1, f2, dim), on=f1, how='left')
# Out:
# 100%|██████████| 4/4 [00:40<00:00, 10.20s/it]

# %%
def get_tfidf(data_, colname, max_features):
    data = data_.copy()

    def f(x):
        x = [i for i in x if type(i) == str]
        return ','.join(x)

    df_tmp = df_log.groupby(['userid'], as_index=False)[
        colname].agg({'list': f})
    text = list(df_tmp['list'].fillna('nan').values)

    tf = TfidfVectorizer(min_df=0,
                         ngram_range=(1, 1),
                         max_features=max_features)
    tf.fit(text)
    X = tf.transform(text)

    df_tfidf = pd.DataFrame(X.todense())
    df_tfidf.columns = [f'{colname}_tfidf{i}' for i in range(max_features)]
    df_tfidf['userid'] = df_tmp['userid']

    return df_tfidf

# %%
for f, dim in [['eventname', 16]]:
    df_tfidf = get_tfidf(df_log, f, dim)
    df_feature = df_feature.merge(df_tfidf, how='left')

# %%
# label encoder
def stat(df, df_merge, group_by, agg):
    group = df.groupby(group_by).agg(agg)

    columns = []
    for on, methods in agg.items():
        for method in methods:
            columns.append('{}_{}_{}'.format('_'.join(group_by), on, method))
    group.columns = columns
    group.reset_index(inplace=True)
    df_merge = df_merge.merge(group, on=group_by, how='left')

    del (group)
    gc.collect()
    return df_merge
    
def statis_feat(df_know, df_unknow):
    df_unknow = stat(df_know, df_unknow, ['productId'], {'target': ['mean', 'sum']})
    df_unknow = stat(df_know, df_unknow, ['region'], {'target': ['mean']})
    df_unknow = stat(df_know, df_unknow, ['uadevice'], {'target': ['mean']})
    df_unknow = stat(df_know, df_unknow, ['uadevice', 'productId'], {'target': ['mean']})

    return df_unknow


df_train = df_feature[~df_feature['target'].isnull()]
df_train = df_train.reset_index(drop=True)
df_test = df_feature[df_feature['target'].isnull()]
df_test = df_test.reset_index(drop=True)
   
df_stas_feat = None
kf = GroupKFold(n_splits=5)
for train_index, val_index in kf.split(
        df_train, df_train, df_train['userid']):
    df_fold_train = df_train.iloc[train_index]
    df_fold_val = df_train.iloc[val_index]
    
    df_fold_val = statis_feat(df_fold_train, df_fold_val)
    df_stas_feat = pd.concat([df_stas_feat, df_fold_val], axis=0)
    
    del(df_fold_train)
    del(df_fold_val)
    gc.collect()

df_test = statis_feat(df_train, df_test)
df_feature = pd.concat([df_stas_feat, df_test], axis=0)

del(df_stas_feat)
del(df_train)
del(df_test)
gc.collect()
# Out:
# 43

# %%
start_time = time.time()

df_temp = df_log[df_log['eventname'] ==
                 'h320057'][['userid', 'productId']].copy()
df_temp = df_temp.groupby(['userid'])['productId'].agg(
    {'list': list}).reset_index()
df_temp.columns = ['userid', 'click_productIds']
user_click_product_dict = dict(
    zip(df_temp['userid'].values, df_temp['click_productIds'].values))


def func_sim_last(x):
    productId = x['productId']
    userid = x['userid']

    emb_size = 16
    if os.path.exists('model/w2v_productId_{}.m'.format(emb_size)):
        model = Word2Vec.load('model/w2v_productId_{}.m'.format(emb_size))
    else:
        raise Exception('no model!')

    sim = 0
    try:
        click_products = user_click_product_dict[userid]
        sim = model.similarity(click_products[-1], productId)
    except Exception as _:
        pass

    return sim


def func_sim_rolling_mean(x, window):
    productId = x['productId']
    userid = x['userid']

    emb_size = 16
    if os.path.exists('model/w2v_productId_{}.m'.format(emb_size)):
        model = Word2Vec.load('model/w2v_productId_{}.m'.format(emb_size))
    else:
        raise Exception('no model!')

    sim_list = []
    if userid in user_click_product_dict:
        click_products = user_click_product_dict[userid][-window:]
        for p in click_products:
            try:
                sim = model.similarity(p, productId)
                sim_list.append(sim)
            except Exception as _:
                pass
    else:
        return 0

    return np.mean(sim_list)


if os.path.exists('data/last_product_sim.pkl'):
    df = pd.read_pickle('data/last_product_sim.pkl')
    df_feature = df_feature.merge(df, how='left')
else:
    df_feature['last_product_sim'] = df_feature[[
        'userid', 'productId']].parallel_apply(func_sim_last, axis=1)
    df_feature[['userid', 'productId', 'last_product_sim']
               ].to_pickle('data/last_product_sim.pkl')


# if os.path.exists('data/product_sim_rolling3_mean.pkl'):
#     df = pd.read_pickle('data/product_sim_rolling3_mean.pkl')
#     df_feature = df_feature.merge(df, how='left')
# else:
#     df_feature['product_sim_rolling3_mean'] = df_feature[[
#         'userid', 'productId']].parallel_apply(lambda x: func_sim_rolling_mean(x, 3), axis=1)
#     df_feature[['userid', 'productId', 'product_sim_rolling3_mean']
#               ].to_pickle('data/product_sim_rolling3_mean.pkl')

end_time = time.time()
print(end_time - start_time)

del df_temp
gc.collect()
# Out:
# 1.5381317138671875
# 84

# %%
df_feature.head()
# Out:
#    userid       productId  target uaos nettype  uadevice region city  hour  \
# 0   19823  20180530244125     0.0  iOS    Wifi  iPhone 7    浙江省   宁波    10
# 1   19823  20180531263676     0.0  iOS    Wifi  iPhone 7    浙江省   宁波    10
# 2   19823  20181010361410     0.0  iOS    Wifi  iPhone 7    浙江省   宁波    10
# 3   19823  20200221398853     0.0  iOS    Wifi  iPhone 7    浙江省   宁波    10
# 4   19823   2019123176289     0.0  iOS    Wifi  iPhone 7    浙江省   宁波    10
#
#    last_7day_productId_count  last_7day_userid_productId_count  \
# 0                      275.0                               NaN
# 1                     5469.0                               NaN
# 2                    33610.0                               NaN
# 3                        4.0                               NaN
# 4                    10247.0                               NaN
#
#   is_in_click_history  productId_count  userid_productId_count  uaos_count  \
# 0               False            753.0                     NaN      372465
# 1               False          13733.0                     NaN      372465
# 2                True          76338.0                     6.0      372465
# 3               False              8.0                     NaN      372465
# 4               False          34824.0                     NaN      372465
#
#    lat_mean  url_startTime_eventtime_diff_mean  hour_std  eventtime_max  \
# 0   29.8782                       32077.133333  1.410759  1587363640328
# 1   29.8782                       32077.133333  1.410759  1587363640328
# 2   29.8782                       32077.133333  1.410759  1587363640328
# 3   29.8782                       32077.133333  1.410759  1587363640328
# 4   29.8782                       32077.133333  1.410759  1587363640328
#
#    eventname_11010479_count  eventname_329000048_count  \
# 0                       8.0                        NaN
# 1                       8.0                        NaN
# 2                       8.0                        NaN
# 3                       8.0                        NaN
# 4                       8.0                        NaN
#
#    eventname_HCZ_O00013865_count  userid_title_emb_0  userid_title_emb_1  \
# 0                            4.0           -0.169623            -0.87515
# 1                            4.0           -0.169623            -0.87515
# 2                            4.0           -0.169623            -0.87515
# 3                            4.0           -0.169623            -0.87515
# 4                            4.0           -0.169623            -0.87515
#
#    userid_title_emb_2  userid_title_emb_3  userid_title_emb_4  \
# 0            1.442965            0.283776           -1.290443
# 1            1.442965            0.283776           -1.290443
# 2            1.442965            0.283776           -1.290443
# 3            1.442965            0.283776           -1.290443
# 4            1.442965            0.283776           -1.290443
#
#    userid_title_emb_5  userid_title_emb_6  userid_title_emb_7  \
# 0            1.338506             0.07655           -0.496715
# 1            1.338506             0.07655           -0.496715
# 2            1.338506             0.07655           -0.496715
# 3            1.338506             0.07655           -0.496715
# 4            1.338506             0.07655           -0.496715
#
#    userid_title_emb_8  userid_title_emb_9  userid_title_emb_10  \
# 0            0.021581            0.403609            -0.241506
# 1            0.021581            0.403609            -0.241506
# 2            0.021581            0.403609            -0.241506
# 3            0.021581            0.403609            -0.241506
# 4            0.021581            0.403609            -0.241506
#
#    userid_title_emb_11  userid_title_emb_12  userid_title_emb_13  \
# 0             0.919572            -0.595706             0.458613
# 1             0.919572            -0.595706             0.458613
# 2             0.919572            -0.595706             0.458613
# 3             0.919572            -0.595706             0.458613
# 4             0.919572            -0.595706             0.458613
#
#    userid_title_emb_14  userid_title_emb_15  userid_productId_emb_0  \
# 0             0.405169             0.877267                 0.02558
# 1             0.405169             0.877267                 0.02558
# 2             0.405169             0.877267                 0.02558
# 3             0.405169             0.877267                 0.02558
# 4             0.405169             0.877267                 0.02558
#
#    userid_productId_emb_1  userid_productId_emb_2  userid_productId_emb_3  \
# 0                0.554176               -0.775753               -0.637584
# 1                0.554176               -0.775753               -0.637584
# 2                0.554176               -0.775753               -0.637584
# 3                0.554176               -0.775753               -0.637584
# 4                0.554176               -0.775753               -0.637584
#
#    userid_productId_emb_4  userid_productId_emb_5  userid_productId_emb_6  \
# 0                -0.27416                 0.71421               -0.878604
# 1                -0.27416                 0.71421               -0.878604
# 2                -0.27416                 0.71421               -0.878604
# 3                -0.27416                 0.71421               -0.878604
# 4                -0.27416                 0.71421               -0.878604
#
#    userid_productId_emb_7  userid_productId_emb_8  userid_productId_emb_9  \
# 0               -1.512585               -0.195261                0.242496
# 1               -1.512585               -0.195261                0.242496
# 2               -1.512585               -0.195261                0.242496
# 3               -1.512585               -0.195261                0.242496
# 4               -1.512585               -0.195261                0.242496
#
#    userid_productId_emb_10  userid_productId_emb_11  userid_productId_emb_12  \
# 0                 0.304706                 0.280001                 0.014035
# 1                 0.304706                 0.280001                 0.014035
# 2                 0.304706                 0.280001                 0.014035
# 3                 0.304706                 0.280001                 0.014035
# 4                 0.304706                 0.280001                 0.014035
#
#    userid_productId_emb_13  userid_productId_emb_14  userid_productId_emb_15  \
# 0                 0.535602                -0.934907                 1.104328
# 1                 0.535602                -0.934907                 1.104328
# 2                 0.535602                -0.934907                 1.104328
# 3                 0.535602                -0.934907                 1.104328
# 4                 0.535602                -0.934907                 1.104328
#
#    userid_hzcModule_emb_0  userid_hzcModule_emb_1  userid_hzcModule_emb_2  \
# 0                0.398499                1.030108                -0.60033
# 1                0.398499                1.030108                -0.60033
# 2                0.398499                1.030108                -0.60033
# 3                0.398499                1.030108                -0.60033
# 4                0.398499                1.030108                -0.60033
#
#    userid_hzcModule_emb_3  userid_hzcModule_emb_4  userid_hzcModule_emb_5  \
# 0               -0.206224               -0.404548                0.730864
# 1               -0.206224               -0.404548                0.730864
# 2               -0.206224               -0.404548                0.730864
# 3               -0.206224               -0.404548                0.730864
# 4               -0.206224               -0.404548                0.730864
#
#    userid_hzcModule_emb_6  userid_hzcModule_emb_7  userid_hzcModule_emb_8  \
# 0                0.277349               -0.571467               -0.179171
# 1                0.277349               -0.571467               -0.179171
# 2                0.277349               -0.571467               -0.179171
# 3                0.277349               -0.571467               -0.179171
# 4                0.277349               -0.571467               -0.179171
#
#    userid_hzcModule_emb_9  userid_hzcModule_emb_10  userid_hzcModule_emb_11  \
# 0                0.322232                 0.608569                -1.916789
# 1                0.322232                 0.608569                -1.916789
# 2                0.322232                 0.608569                -1.916789
# 3                0.322232                 0.608569                -1.916789
# 4                0.322232                 0.608569                -1.916789
#
#    userid_hzcModule_emb_12  userid_hzcModule_emb_13  userid_hzcModule_emb_14  \
# 0                  1.02683                 0.378506                -1.535189
# 1                  1.02683                 0.378506                -1.535189
# 2                  1.02683                 0.378506                -1.535189
# 3                  1.02683                 0.378506                -1.535189
# 4                  1.02683                 0.378506                -1.535189
#
#    userid_hzcModule_emb_15  userid_eventname_emb_0  userid_eventname_emb_1  \
# 0                -0.616795                0.405953                0.805352
# 1                -0.616795                0.405953                0.805352
# 2                -0.616795                0.405953                0.805352
# 3                -0.616795                0.405953                0.805352
# 4                -0.616795                0.405953                0.805352
#
#    userid_eventname_emb_2  userid_eventname_emb_3  userid_eventname_emb_4  \
# 0                0.462744               -0.576125               -0.057167
# 1                0.462744               -0.576125               -0.057167
# 2                0.462744               -0.576125               -0.057167
# 3                0.462744               -0.576125               -0.057167
# 4                0.462744               -0.576125               -0.057167
#
#    userid_eventname_emb_5  userid_eventname_emb_6  userid_eventname_emb_7  \
# 0                0.498681                0.069567                0.647471
# 1                0.498681                0.069567                0.647471
# 2                0.498681                0.069567                0.647471
# 3                0.498681                0.069567                0.647471
# 4                0.498681                0.069567                0.647471
#
#    userid_eventname_emb_8  userid_eventname_emb_9  userid_eventname_emb_10  \
# 0                0.040253                0.294924                 0.424642
# 1                0.040253                0.294924                 0.424642
# 2                0.040253                0.294924                 0.424642
# 3                0.040253                0.294924                 0.424642
# 4                0.040253                0.294924                 0.424642
#
#    userid_eventname_emb_11  userid_eventname_emb_12  userid_eventname_emb_13  \
# 0                -0.364401                 0.111598                 0.166745
# 1                -0.364401                 0.111598                 0.166745
# 2                -0.364401                 0.111598                 0.166745
# 3                -0.364401                 0.111598                 0.166745
# 4                -0.364401                 0.111598                 0.166745
#
#    userid_eventname_emb_14  userid_eventname_emb_15  eventname_tfidf0  \
# 0                 0.611307                 0.491611          0.206251
# 1                 0.611307                 0.491611          0.206251
# 2                 0.611307                 0.491611          0.206251
# 3                 0.611307                 0.491611          0.206251
# 4                 0.611307                 0.491611          0.206251
#
#    eventname_tfidf1  eventname_tfidf2  eventname_tfidf3  eventname_tfidf4  \
# 0           0.32708          0.565596          0.152609          0.113527
# 1           0.32708          0.565596          0.152609          0.113527
# 2           0.32708          0.565596          0.152609          0.113527
# 3           0.32708          0.565596          0.152609          0.113527
# 4           0.32708          0.565596          0.152609          0.113527
#
#    eventname_tfidf5  eventname_tfidf6  eventname_tfidf7  eventname_tfidf8  \
# 0          0.369029          0.046452          0.156539          0.440848
# 1          0.369029          0.046452          0.156539          0.440848
# 2          0.369029          0.046452          0.156539          0.440848
# 3          0.369029          0.046452          0.156539          0.440848
# 4          0.369029          0.046452          0.156539          0.440848
#
#    eventname_tfidf9  eventname_tfidf10  eventname_tfidf11  eventname_tfidf12  \
# 0          0.151847                0.0           0.039327           0.152035
# 1          0.151847                0.0           0.039327           0.152035
# 2          0.151847                0.0           0.039327           0.152035
# 3          0.151847                0.0           0.039327           0.152035
# 4          0.151847                0.0           0.039327           0.152035
#
#    eventname_tfidf13  eventname_tfidf14  eventname_tfidf15  \
# 0           0.151649            0.23168            0.11322
# 1           0.151649            0.23168            0.11322
# 2           0.151649            0.23168            0.11322
# 3           0.151649            0.23168            0.11322
# 4           0.151649            0.23168            0.11322
#
#    productId_target_mean  productId_target_sum  region_target_mean  \
# 0               0.011983                  66.0            0.046137
# 1               0.054285                 299.0            0.046137
# 2               0.217683                1199.0            0.046137
# 3               0.000545                   3.0            0.046137
# 4               0.068083                 375.0            0.046137
#
#    uadevice_target_mean  uadevice_productId_target_mean  last_product_sim
# 0              0.043245                        0.000000         -0.170382
# 1              0.043245                        0.050725         -0.058608
# 2              0.043245                        0.181159         -0.110004
# 3              0.043245                        0.000000         -0.056762
# 4              0.043245                        0.043478          0.141887

# %%
df_feature.shape
# Out:
# (719138, 108)

# %% [markdown]
# # 模型训练

# %%
le_productId = LabelEncoder()
df_feature['productId'] = le_productId.fit_transform(
    df_feature['productId'].astype('str')).astype('int')
    
for f in list(df_feature.select_dtypes('object')):
    le = LabelEncoder()
    df_feature[f] = le.fit_transform(
        df_feature[f].astype('str')).astype('int')

# %%
df_feature.to_pickle('data/feature.pkl')

# %%
df_train = df_feature[df_feature['target'].notnull()]
df_test = df_feature[df_feature['target'].isnull()]

gc.collect()

df_train['weight'] = 1
df_train['weight'] = df_train['userid'].map(
    df_train.loc[df_train['target'] == 1].groupby(['userid'])['productId'].nunique())
df_train['weight'] = 1 / df_train['weight']

# %%
ycol = 'target'
feature_names = list(
    filter(lambda x: x not in [ycol, 'weight'], df_train.columns))

model = lgb.LGBMClassifier(num_leaves=64,
                           max_depth=10,
                           learning_rate=0.01,
                           n_estimators=100000,
                           subsample=0.8,
                           feature_fraction=0.8,
                           reg_alpha=0.5,
                           reg_lambda=0.5,
                           random_state=seed,
                           metric=None)



oof = []
prediction = df_test[['userid', 'productId']]
prediction['pred'] = 0
df_importance_list = []

fold_num = 5

kfold = GroupKFold(n_splits=fold_num)
for fold_id, (trn_idx, val_idx) in enumerate(kfold.split(
        df_train[feature_names], df_train[ycol], df_train['userid'])):
    X_train = df_train.iloc[trn_idx][feature_names]
    Y_train = df_train.iloc[trn_idx][ycol]

    X_val = df_train.iloc[val_idx][feature_names]
    Y_val = df_train.iloc[val_idx][ycol]

    print('\nFold_{} Training ================================\n'.format(fold_id+1))

    lgb_model = model.fit(X_train,
                          Y_train,
                          eval_names=['train', 'valid'],
                          eval_set=[(X_train, Y_train), (X_val, Y_val)],
                          verbose=500,
                          eval_metric='auc',
                          sample_weight=df_train.iloc[trn_idx]['weight'],
                          early_stopping_rounds=50)

    pred_val = lgb_model.predict_proba(
        X_val, num_iteration=lgb_model.best_iteration_)[:, 1]
    df_oof = df_train.iloc[val_idx][[
        'userid', 'productId', ycol]].copy()
    df_oof['pred'] = pred_val
    oof.append(df_oof)

    pred_test = lgb_model.predict_proba(
        df_test[feature_names], num_iteration=lgb_model.best_iteration_)[:, 1]
    prediction['pred'] += pred_test / fold_num

    df_importance = pd.DataFrame({
        'column': feature_names,
        'importance': lgb_model.feature_importances_,
    })
    df_importance_list.append(df_importance)

    del lgb_model, pred_val, pred_test, X_train, Y_train, X_val, Y_val
    gc.collect()
# Out:
# Fold_1 Training ================================
#
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [355]	train's auc: 0.890241	valid's auc: 0.842665
#
# Fold_2 Training ================================
#
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [295]	train's auc: 0.887252	valid's auc: 0.842548
#
# Fold_3 Training ================================
#
# Training until validation scores don't improve for 50 rounds.
# [500]	train's auc: 0.899651	valid's auc: 0.843369
# Early stopping, best iteration is:
# [722]	train's auc: 0.91059	valid's auc: 0.844063
#
# Fold_4 Training ================================
#
# Training until validation scores don't improve for 50 rounds.
# [500]	train's auc: 0.901586	valid's auc: 0.841461
# Early stopping, best iteration is:
# [513]	train's auc: 0.902216	valid's auc: 0.841522
#
# Fold_5 Training ================================
#
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [359]	train's auc: 0.89041	valid's auc: 0.841132

# %% [markdown]
# # 模型训练

# %%
df_importance = pd.concat(df_importance_list)
df_importance = df_importance.groupby(['column'])['importance'].agg(
    'mean').sort_values(ascending=False).reset_index()
df_importance
# Out:
#                                 column  importance
# 0                productId_target_mean      1716.8
# 1               userid_productId_count       994.2
# 2                     last_product_sim       887.4
# 3                            productId       732.8
# 4            last_7day_productId_count       678.4
# 5       uadevice_productId_target_mean       628.2
# 6                               userid       489.2
# 7                        eventtime_max       465.0
# 8    url_startTime_eventtime_diff_mean       461.4
# 9                 uadevice_target_mean       442.0
# 10                            lat_mean       399.6
# 11                     productId_count       351.4
# 12                            hour_std       350.8
# 13                productId_target_sum       340.8
# 14             userid_productId_emb_14       336.2
# 15              userid_eventname_emb_2       332.4
# 16             userid_eventname_emb_10       324.6
# 17                  region_target_mean       316.6
# 18                            uadevice       312.6
# 19              userid_hzcModule_emb_8       300.0
# 20             userid_hzcModule_emb_14       296.6
# 21              userid_eventname_emb_4       283.8
# 22    last_7day_userid_productId_count       281.6
# 23                  userid_title_emb_2       281.6
# 24                  userid_title_emb_1       281.4
# 25              userid_eventname_emb_6       279.8
# 26             userid_hzcModule_emb_11       271.8
# 27              userid_productId_emb_4       268.4
# 28             userid_eventname_emb_15       267.2
# 29              userid_hzcModule_emb_2       265.0
# 30             userid_productId_emb_15       262.6
# 31              userid_eventname_emb_8       261.0
# 32                 userid_title_emb_11       260.6
# 33                                city       259.6
# 34              userid_hzcModule_emb_9       258.2
# 35                 userid_title_emb_12       256.2
# 36                 userid_title_emb_13       253.4
# 37              userid_hzcModule_emb_7       251.2
# 38              userid_eventname_emb_7       250.8
# 39            eventname_11010479_count       250.2
# 40              userid_productId_emb_6       249.2
# 41             userid_hzcModule_emb_15       248.2
# 42                    eventname_tfidf0       247.4
# 43             userid_productId_emb_12       245.0
# 44             userid_eventname_emb_13       241.6
# 45                  userid_title_emb_6       241.0
# 46              userid_productId_emb_7       238.4
# 47              userid_eventname_emb_9       237.4
# 48                              region       231.6
# 49                  userid_title_emb_7       231.2
# 50              userid_eventname_emb_1       229.0
# 51                  userid_title_emb_3       228.0
# 52                  userid_title_emb_0       226.2
# 53              userid_hzcModule_emb_0       224.8
# 54             userid_eventname_emb_12       223.6
# 55                 userid_title_emb_14       221.8
# 56             userid_eventname_emb_11       221.0
# 57       eventname_HCZ_O00013865_count       219.4
# 58                  userid_title_emb_4       216.8
# 59              userid_productId_emb_3       214.8
# 60              userid_hzcModule_emb_6       211.6
# 61                 userid_title_emb_10       211.4
# 62              userid_hzcModule_emb_1       211.0
# 63              userid_productId_emb_2       209.4
# 64              userid_hzcModule_emb_5       203.4
# 65             userid_productId_emb_10       201.0
# 66              userid_productId_emb_0       198.8
# 67             userid_eventname_emb_14       198.0
# 68              userid_eventname_emb_3       198.0
# 69              userid_productId_emb_1       198.0
# 70                 userid_title_emb_15       195.8
# 71              userid_eventname_emb_0       195.2
# 72                  userid_title_emb_9       194.8
# 73                  userid_title_emb_5       193.0
# 74              userid_productId_emb_8       191.4
# 75             userid_hzcModule_emb_12       188.0
# 76              userid_hzcModule_emb_4       187.8
# 77                   eventname_tfidf15       186.0
# 78                    eventname_tfidf9       182.2
# 79             userid_hzcModule_emb_13       179.8
# 80                  userid_title_emb_8       176.8
# 81                 is_in_click_history       173.8
# 82                                hour       172.8
# 83              userid_hzcModule_emb_3       171.6
# 84                    eventname_tfidf5       171.4
# 85              userid_productId_emb_9       167.6
# 86             userid_hzcModule_emb_10       162.4
# 87                    eventname_tfidf2       155.2
# 88                    eventname_tfidf7       153.2
# 89                    eventname_tfidf8       153.0
# 90              userid_eventname_emb_5       149.0
# 91             userid_productId_emb_13       148.8
# 92                   eventname_tfidf10       147.0
# 93              userid_productId_emb_5       141.2
# 94                    eventname_tfidf4       135.8
# 95                    eventname_tfidf1       135.8
# 96                    eventname_tfidf3       132.2
# 97                   eventname_tfidf13       130.2
# 98                   eventname_tfidf11       128.8
# 99                   eventname_tfidf12       127.6
# 100                  eventname_tfidf14       126.6
# 101            userid_productId_emb_11       118.8
# 102                   eventname_tfidf6        96.6
# 103          eventname_329000048_count        84.0
# 104                            nettype        39.6
# 105                               uaos         1.2
# 106                         uaos_count         1.0

# %%
# 计分
def cal_score(df_):
    df = df_.copy()
    
    df.sort_values(['userid', 'pred'], ascending = [True, False], inplace = True)
    
    gg = df.groupby(['userid'])
    scores = []
    for _, g in tqdm(gg):
        true_answers = set(g[g['target'] == 1]['productId'].values.tolist())
        if len(true_answers) == 0:
            continue
        
        top3 = set(g.head(3)['productId'].values.tolist())
        true_num = len(true_answers & top3)
        
        if len(true_answers) > 3:
            scores += [true_num / 3]
        else:
            scores += [true_num / len(true_answers)]
            
    return np.mean(scores)

# %%
df_oof = pd.concat(oof)
score = cal_score(df_oof)
print(score)
# Out:
# 100%|██████████| 6885/6885 [00:06<00:00, 1074.60it/s]
# 0.422076978939724

# %%
df_oof.sort_values(['userid', 'pred'], ascending = [True, False], inplace = True)
df_oof.head()
# Out:
#         userid  productId  target      pred
# 341498   18403         12     0.0  0.358166
# 341547   18403         49     0.0  0.117307
# 341504   18403         58     0.0  0.086702
# 341522   18403          4     0.0  0.054798
# 341510   18403          8     0.0  0.048134

# %%
prediction = prediction.sort_values(['userid', 'pred'], ascending = [True, False])
sub = prediction.groupby(['userid']).head(3)[['userid', 'productId']]
sub['productId'] = le_productId.inverse_transform(sub['productId'])
sub_ = sub.copy()
sub = sub.groupby('userid')['productId'].apply(list).reset_index()[['userid']]
sub[['pred1', 'pred2', 'pred3']] = pd.DataFrame(list(sub_.groupby('userid')['productId'].apply(list).values))

# %%
df_oof['productId'] = le_productId.inverse_transform(df_oof['productId'])
df_oof.to_csv('prob/oof_{}.csv'.format(score), index=False)
prediction['productId'] = le_productId.inverse_transform(prediction['productId'])
prediction.to_csv('prob/sub_{}.csv'.format(score), index=False)

# %%
sub.head()
# Out:
#    userid           pred1           pred2           pred3
# 0   25863  20180531390867  20200407796159  20200301448260
# 1   27379  20200407796159  20200301448260  20181010361410
# 2   28060  20200407796159  20200301448260  20181010361410
# 3   30799  20200407796159  20181010361410  20200301448260
# 4   30960   2019123176289  20200407796159   2020010375676

# %%
sub.to_csv('sub/{}.csv'.format(score),index=False)
sub.to_csv('sub/sub.csv',index=False)

# %%
# !wget -nv -O kesci_submit https://cdn.kesci.com/submit_tool/v4/kesci_submit&&chmod +x kesci_submit
# !./kesci_submit -token fab409df432da998 -file /home/kesci/work/sub/sub.csv
# Out:
# wget: /opt/conda/lib/libcrypto.so.1.0.0: no version information available (required by wget)
# wget: /opt/conda/lib/libssl.so.1.0.0: no version information available (required by wget)
# wget: /opt/conda/lib/libssl.so.1.0.0: no version information available (required by wget)
# 2020-06-25 16:29:32 URL:https://cdn.kesci.com/submit_tool/v4/kesci_submit [7357446/7357446] -> "kesci_submit" [1]
# Kesci Submit Tool 4.0.0
#
# > 已验证Token
# > 提交文件 /home/kesci/work/sub/sub.csv (247.98 KiB), Target Qiniu
# > 已上传 100 %
# > 文件已上传
# > 服务器响应: 200 提交成功，请等待评审完成
# > 提交完成

# %%
# !wget -nv -O kesci_submit https://cdn.kesci.com/submit_tool/v4/kesci_submit&&chmod +x kesci_submit
# !./kesci_submit -token fab409df432da998 -file /home/kesci/work/prob/oof_0.42297264584846284.csv

# %%
prediction.head()
# Out:
#         userid       productId      pred
# 426912   25863  20180531390867  0.213187
# 426878   25863  20200407796159  0.141481
# 426921   25863  20200301448260  0.108893
# 426872   25863  20181010361410  0.085165
# 426927   25863  20200218174314  0.082472

# %%
prediction.shape
# Out:
# (292268, 3)
